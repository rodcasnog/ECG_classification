# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pywt
import time

# %%
zip_file_path = './task2.zip'
extraction_directory = 'extracted_images/'

# %%
y_train = pd.read_csv(extraction_directory + 'y_train.csv', index_col='id')
y_train_np = y_train.to_numpy()

# %%
X_train = pd.read_csv(extraction_directory + 'X_train.csv', index_col='id')
X_train_np = X_train.to_numpy()

# %%
def replicate_row(row):
    # Find the length of the non-NaN part
    valid_length = np.argmax(row.isna())
    valid_length = valid_length if valid_length > 0 else len(row)

    # Repeat the non-NaN part and truncate to match the original length
    repeated = np.tile(row[:valid_length], len(row) // valid_length + 1)[:len(row)]
    return pd.Series(repeated)

start = time.time()

X_train_periodic = X_train.apply(replicate_row, axis=1)

end = time.time()
print(f"Time taken: {end - start} seconds")
# Out:
# Time taken: 1.0099592208862305 seconds

# %%
X_train_periodic_np = X_train_periodic.to_numpy()

# %%
from numpy.random import RandomState

prng = RandomState(1)

def augment_signal(signal, max_shift, scaling_factor_range, noise_level, max_freq_change):
    signal = signal.copy()
    # Time Shifting
    if max_shift > 0:
        shift = prng.randint(-max_shift, max_shift)
        signal = np.roll(signal, shift)

    # Scaling
    if scaling_factor_range > 0:
        signal *= prng.uniform(1 - scaling_factor_range, 1 + scaling_factor_range)

    # Adding Noise
    if noise_level > 0:
        signal += pd.DataFrame(prng.normal(0, noise_level, size=signal.size + 500)).rolling(window=500).median().to_numpy().squeeze()[500:]

    # Frequency Change (Resampling)
    if max_freq_change > 0:
        freq_change = prng.uniform(1 - max_freq_change, 1 + max_freq_change)
        resample_size = int(len(signal) * freq_change)
        if freq_change > 1:
            signal = np.interp(np.linspace(0, 1, resample_size), np.linspace(0, 1, len(signal)), signal)[:signal.size]
        elif freq_change < 1:
            signal = np.tile(np.interp(np.linspace(0, 1, resample_size), np.linspace(0, 1, len(signal)), signal), 2)[:signal.size]
    return signal

# %%
class_distribution = y_train.apply(lambda x: {i: x[x == i].count() for i in range(4)})['y']
print('Original:')
for name in class_distribution:
    print(str(name) + ': {:} = {:.2%}'.format(class_distribution[name] , class_distribution[name] / y_train_np.size))
print('')

y_train_np = y_train.to_numpy().squeeze()

# Parameters for augmentation
max_shift = 450  # Maximum shift for time shifting
scaling_factor_range = 0.05  # Scaling factor range for scaling
noise_level = 1500  # Noise level for adding noise
max_freq_change = 0.01  # Maximum frequency change for resampling

# Augmenting the dataset
X_augmented = []
y_augmented = []

for class_label in [1]*4 + [2]*1 + [3]*12:
    for i in range(X_train.shape[0]):
        if y_train_np[i] == class_label:  # Define your threshold
            augmented_signal = augment_signal(X_train_periodic_np[i], max_shift, scaling_factor_range, noise_level, max_freq_change)
            X_augmented.append(augmented_signal)
            y_augmented.append(class_label)

# Convert augmented data to numpy arrays and add to original dataset
X_augmented = np.array(X_augmented)
y_augmented = np.array(y_augmented)

X_train_extended_np = np.concatenate((X_train_periodic_np, X_augmented))
y_train_extended_np = np.concatenate((y_train_np, y_augmented))

X_train_extended = pd.DataFrame(X_train_extended_np, columns=X_train.columns)
y_train_extended = pd.DataFrame(y_train_extended_np, columns=y_train.columns)

class_distribution_extended = y_train_extended.apply(lambda x: {i: x[x == i].count() for i in range(4)})['y']
print('Extended:')
for name in class_distribution_extended:
    print(str(name) + ': {:} = {:.2%}'.format(class_distribution_extended[name], class_distribution_extended[name] / y_train_extended_np.size))
# Out:
# Original:
# 0: 3030 = 59.21%
# 1: 443 = 8.66%
# 2: 1474 = 28.81%
# 3: 170 = 3.32%
#
# Extended:
# 0: 3030 = 29.13%
# 1: 2215 = 21.29%
# 2: 2948 = 28.34%
# 3: 2210 = 21.24%

# %%
# Retrieve one sample recording per class for plotting
num_classes = 4
num = 10
offset = 0
sample_signal_ids = []
for class_id in range(num_classes):
    sample_signal_ids.append(X_train.index[np.argwhere(y_train['y'].to_numpy() == class_id)[offset:offset+num].squeeze().tolist()].to_list())
    
# Print indices of the sample signals
sample_signal_ids
# Out:
# [[0, 1, 2, 6, 9, 11, 12, 13, 15, 19],
#  [3, 5, 7, 16, 29, 53, 77, 96, 108, 113],
#  [4, 8, 10, 14, 17, 18, 20, 22, 26, 28],
#  [30, 33, 71, 74, 102, 103, 171, 197, 201, 269]]

# %%
# Retrieve one sample recording per class for plotting
num_classes = 4
num = 10
offset = 0
sample_signal_ids_last = []
for class_id in range(num_classes):
    sample_signal_ids_last.append(X_train.index[np.argwhere(y_train['y'].to_numpy() == class_id).squeeze().tolist()[-offset-num-1:-offset-1]].to_list())
    
# Print indices of the sample signals
sample_signal_ids_last
# Out:
# [[5100, 5102, 5104, 5105, 5106, 5107, 5108, 5109, 5113, 5114],
#  [4971, 4974, 5027, 5051, 5064, 5078, 5084, 5094, 5097, 5103],
#  [5058, 5068, 5073, 5080, 5082, 5085, 5089, 5098, 5101, 5111],
#  [4904, 4907, 4940, 4950, 4969, 4973, 4980, 5013, 5031, 5036]]

# %%
# Retrieve one sample recording per class for plotting
num_classes = 4
num = 10
offset = 0
sample_signal_ids_extended_last = []
for class_id in range(num_classes):
    sample_signal_ids_extended_last.append(X_train_extended.index[np.argwhere(y_train_extended['y'].to_numpy() == class_id).squeeze().tolist()[-offset-num-1:-offset-1]].to_list())
    
# Print indices of the sample signals
sample_signal_ids_extended_last
# Out:
# [[5100, 5102, 5104, 5105, 5106, 5107, 5108, 5109, 5113, 5114],
#  [6878, 6879, 6880, 6881, 6882, 6883, 6884, 6885, 6886, 6887],
#  [8352, 8353, 8354, 8355, 8356, 8357, 8358, 8359, 8360, 8361],
#  [10392, 10393, 10394, 10395, 10396, 10397, 10398, 10399, 10400, 10401]]

# %% [markdown]
# num = 10
# fig, axs = plt.subplots(4*num, 1, figsize=(45, 30*num))
# plot_length = 1000
# seconds = np.arange(0, plot_length) / 150
# x_labels = range(0,int(seconds[-1]),3)
#
# for class_id in range(4):
#     for i in range(num):
#         ax = axs[num*class_id + i]
#         ax.set_title("Class {}".format(class_id))
#         ax.plot(seconds, X_train_extended_np[sample_signal_ids_extended_last[class_id][i], 0:plot_length:1], color='g', label='modified')
#         ax.plot(seconds, X_train_np[sample_signal_ids_last[class_id][i], 0:plot_length:1], color='k', label='original')
#         ax.set_xticks(x_labels)
#         ax.legend()
#         ax.grid()
# fig.tight_layout()
#
# ax = fig.add_subplot(111, frameon=False)
# plt.show()

# %%
def get_median_filter_width(sampling_rate, duration):
    res = int( sampling_rate*duration )
    res += ((res%2) - 1) # needs to be an odd number
    return res

# ms_flt_array = [0.2,0.6]
ms_flt_array = [0.4,0.8]

def filter_line(data, ms_flt_array):
    data = data.copy()

    for i in range(0, len(ms_flt_array)):
        window_size = get_median_filter_width(300, ms_flt_array[i])

        data -= data.apply(lambda x: x.rolling(window=window_size, center=True, min_periods=1).median(), axis=1)

    return data

X_train_filtered = filter_line(X_train_extended, ms_flt_array)
X_train_filtered_np = X_train_filtered.to_numpy()

# %%
total_length = X_train.shape[1]

def denoise_signal_with_selective_thresholding(signal, wavelet, level, qrs_band=(5, 15), sampling_rate=300, dampening=2):
    # Decompose to get the wavelet coefficients
    coeffs = pywt.wavedec(signal, wavelet, level=level)

    # Calculate the frequency bands for each level of decomposition
    freqs = pywt.scale2frequency(wavelet, [1, 2, 4, 8, 16, 32, 64]) * sampling_rate

    # Calculate a universal threshold
    sigma = np.median(np.abs(coeffs[-level])) / 0.6745
    threshold = sigma * np.sqrt(2 * np.log(len(signal)))

    # Apply selective thresholding
    new_coeffs = []
    for i, coeff in enumerate(coeffs[1:], start=1):  # Skip the approximation coefficients
        if freqs[i-1] >= qrs_band[0] and freqs[i-1] <= qrs_band[1]:
            # If within QRS band, apply a softer threshold or skip thresholding
            new_coeffs.append(pywt.threshold(coeff, value=threshold/dampening, mode='soft'))
        else:
            # Else, apply the regular threshold
            new_coeffs.append(pywt.threshold(coeff, value=threshold, mode='soft'))
    
    # Reconstruct the signal using modified coefficients
    coeffs[1:] = new_coeffs
    return pywt.waverec(coeffs, wavelet)

def process_signal(signal, wavelet, level, qrs_band=(5, 15), sampling_rate=300, dampening=2):
    global total_length
    # Find the index of the first NaN value
    nan_index = np.argmax(np.isnan(signal))
    if nan_index == 0:  # No NaNs found
        return denoise_signal_with_selective_thresholding(signal, wavelet, level, qrs_band=qrs_band, sampling_rate=sampling_rate, dampening=dampening)
    
    a = np.empty((total_length-nan_index,))
    a[:] = np.nan

    return np.concatenate([denoise_signal_with_selective_thresholding(signal[:nan_index], wavelet, level, qrs_band=qrs_band, sampling_rate=sampling_rate, dampening=dampening), a])[0:total_length]

# %%
wavelet = 'db4'  # Example wavelet, choose as per your requirement
level = 3 # Decomposition level
qrs_band = (50, 150)  # Frequency band of QRS complex in Hz
sampling_rate = 300  # Sampling rate of ECG signal in Hz
dampening = 1

X_train_denoised_np = np.array([process_signal(row, wavelet, level, qrs_band, sampling_rate, dampening)[0:total_length] for row in X_train_filtered_np])
X_train_denoised = pd.DataFrame(data=X_train_denoised_np, columns=X_train_extended.columns, index=X_train_extended.index)

# %%
from biosppy.signals.ecg import correct_rpeaks
from ecgdetectors import Detectors
import biosppy.signals.ecg as ecg

# from sklearn.preprocessing import RobustScaler, StandardScaler

# %%
def normalize_signal(signal):

    detectors = Detectors(300)

    r_peaks = correct_rpeaks(signal, np.asarray(detectors.pan_tompkins_detector(signal)), 300, 0.2)['rpeaks']
    vals_peaks = signal[r_peaks]
    median_peak_val = np.median(vals_peaks[~np.isnan(vals_peaks)])
    
    if median_peak_val != 0:
        if np.isnan(median_peak_val).any():
            print(median_peak_val)
        return signal / median_peak_val
    # else:
    #     print(median_peak_val)
    #     return RobustScaler(quantile_range=(.2,.8)).fit_transform(signal.T).T/5

X_train_transformed_np = np.apply_along_axis(normalize_signal, 1, X_train_denoised_np)
X_train_transformed = pd.DataFrame(data=X_train_transformed_np, columns=X_train_denoised.columns, index=X_train_denoised.index)

# %%
def plot_features(signal):
    
    detectors = Detectors(300)

    r_peaks = correct_rpeaks(signal, np.asarray(detectors.pan_tompkins_detector(signal)), 300, 0.2)['rpeaks']
    
    #print(r_peaks)
    if len(r_peaks) >= 2:
        #print(ecg.extract_heartbeats(signal, r_peaks, 300))
        beats = ecg.extract_heartbeats(signal, r_peaks, 300, before=.5, after=.5)['templates']

        if len(beats) != 0:
            mu = np.mean(beats, axis=0) 
            var = np.std(beats, axis=0)
            md = np.median(beats, axis=0)
            
            plt.plot(range(mu.shape[0]), mu, label='Average HeartBeat')
            # Fill the variance range
            plt.fill_between(range(mu.shape[0]), mu - var, mu + var, linewidth=0, alpha=0.1)
            # Plot a median
            plt.plot(range(md.shape[0]), md, label='Median HeartBeat', color='#CC4F1B')
            plt.legend()

# %% [markdown]
# plt.figure(figsize=(30, 5*num))
#
# for class_id in range(num_classes):
#     for i in range(num):
#         ax = plt.subplot( num, 4, class_id + 4*i + 1)
#         ax.set_title("Class {}".format(class_id))
#         if class_id:
#             ax.set_yticks([])
#         # ax.set_ylim([-700, 1500])
#         ax.grid()
#         plot_features(X_train_transformed.loc[sample_signal_ids[class_id][i]].to_numpy(dtype='float32'))
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(30, 5*num))
#
# for class_id in range(num_classes):
#     for i in range(num):
#         ax = plt.subplot( num, 4, class_id + 4*i + 1)
#         ax.set_title("Class {}".format(class_id))
#         if class_id:
#             ax.set_yticks([])
#         # ax.set_ylim([-700, 1500])
#         ax.grid()
#         plot_features(X_train_transformed.loc[sample_signal_ids_extended_last[class_id][i]].to_numpy(dtype='float32'))
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(30, 5*num))
#
# for class_id in range(num_classes):
#     for i in range(num):
#         ax = plt.subplot( num, 4, class_id + 4*i + 1)
#         ax.set_title("Class {}".format(class_id))
#         if class_id:
#             ax.set_yticks([])
#         # ax.set_ylim([-700, 1500])
#         ax.grid()
#         plot_features(X_train_transformed.loc[sample_signal_ids_last[class_id][i]].to_numpy(dtype='float32'))
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# xlim = (0,18000)
#
# class_to_show = 3
#
# indeces = sample_signal_ids_extended_last[class_to_show]
#
# processed_arr = X_train_transformed_np[indeces]
#
# for i, j in enumerate(indeces):
#
#     processed = processed_arr[i]
#
#     detectors = Detectors(300)
#
#     r_peaks_pan_proc = correct_rpeaks(processed, np.asarray(detectors.pan_tompkins_detector(processed)), 300, .2)['rpeaks']
#
#     plt.figure(figsize=(21, 7*len(indeces)))
#
#     plt.subplot(len(indeces), 1, i+1)
#     plt.plot(processed, label='Denoised Signal', color='black', alpha=.6)
#     plt.vlines(r_peaks_pan_proc, ymin=-2, ymax=2, colors = ['red'], alpha=.4)
#     plt.xlim(xlim)
#     plt.ylim((-1.5,1.5))
#     plt.legend()
#     plt.grid()
#     plt.tight_layout()
# plt.show()

# %%
def rolling_count(arr, total_range, window_size):
    # Initialize a dictionary to keep track of counts
    counts = dict.fromkeys(range(total_range), 0)
    rolling_counts = []

    # Iterate through the array
    for i, num in enumerate(arr):
        # Increment count for the current number
        counts[num] += 1

        # Start counting for windows after reaching the window size
        if i >= window_size:
            # Decrement count for the number that just moved out of the window
            out_of_window_num = arr[i - window_size]
            counts[out_of_window_num] -= 1

        # Append the total count in the current window to the list
        rolling_counts.append(sum(counts.values()))

    return rolling_counts

# %% [markdown]
# def compute_heart_rate(signal, window_fraction=1/5):
#     """
#         window_fraction: only divisors of 180000
#     """
#
#     if isinstance(signal, pd.DataFrame):
#         signal = signal.to_numpy()
#
#     detectors = Detectors(300)
#
#     r_peaks = correct_rpeaks(signal, np.asarray(detectors.pan_tompkins_detector(signal)), 300, 0.2)['rpeaks']
#
#     a = np.zeros_like(signal)
#
#     a[r_peaks] = 1
#
#     window = int(300*60*window_fraction)
#
#     return (pd.DataFrame(a).rolling(window=window, min_periods=1).sum() / window_fraction).iloc[window:]

# %% [markdown]
# a = compute_heart_rate(X_train_transformed.iloc[sample_signal_ids_extended_last[3][1]])
# plt.plot(a);
# plt.hlines(a.describe()[0][[1,3,4,5,6,7]].to_numpy(), 0, 18000);

# %%
def extract_features(signal, window_fraction=1/5):
    
    r_peaks = correct_rpeaks(signal, np.asarray(Detectors(300).pan_tompkins_detector(signal)), 300, 0.2)['rpeaks']
    
    beats = ecg.extract_heartbeats(signal, r_peaks, 300, before=.5, after=.5)['templates']

    if len(beats) == 0:
        raise Exception()

    a = np.zeros_like(signal)    
    a[r_peaks] = 1
    window = int(300*60*window_fraction)

    heart_rate = (pd.DataFrame(a).rolling(window=window, min_periods=1).sum() / window_fraction).iloc[window:].to_numpy()

    # discrete features

    peak_count = r_peaks.size

    peak_mu = np.mean(signal[r_peaks])
    peak_std = np.std(signal[r_peaks])
    peak_md = np.median(signal[r_peaks])
    peak_q1 = np.quantile(signal[r_peaks], q=.1)
    peak_q25 = np.quantile(signal[r_peaks], q=.25)
    peak_q75 = np.quantile(signal[r_peaks], q=.75)
    peak_q9 = np.quantile(signal[r_peaks], q=.9)

    heart_rate_mu = np.mean(heart_rate)
    heart_rate_std = np.std(heart_rate)
    heart_rate_md = np.median(heart_rate)
    heart_rate_q1 = np.quantile(heart_rate, q=.1)
    heart_rate_q25 = np.quantile(heart_rate, q=.25)
    heart_rate_q75 = np.quantile(heart_rate, q=.75)
    heart_rate_q9 = np.quantile(heart_rate, q=.9)

    # continuous features
    
    # mu = np.mean(beats, axis=0) 
    # var = np.std(beats, axis=0)
    # md = np.median(beats, axis=0)

    # quant_1 = np.quantile(beats, q=.1, axis=0)
    # quant_25 = np.quantile(beats, q=.25, axis=0)
    # quant_75 = np.quantile(beats, q=.75, axis=0)
    # quant_9 = np.quantile(beats, q=.9, axis=0)

    return np.array([peak_count,
             peak_mu, peak_std, peak_md, peak_q1, peak_q25, peak_q75, peak_q9,
             heart_rate_mu, heart_rate_std, heart_rate_md, heart_rate_q1, heart_rate_q25, heart_rate_q75, heart_rate_q9])
             # np.ndarray([[mu, var, md, quant_1, quant_25, quant_75, quant_9]])]

# %%
X_train_discrete_features_np = np.array([extract_features(row) for row in X_train_transformed_np])

# %%
# Downscaling
X_train_downsampled_np = X_train_transformed_np[:,:-1:2]
X_train_downsampled = pd.DataFrame(X_train_downsampled_np)

# %%
X_train_ready_np = np.concatenate([X_train_downsampled_np, X_train_discrete_features_np], axis=1)
X_train_ready = pd.DataFrame(X_train_ready_np)

# %%
X_train_ready_np.shape, X_train_downsampled_np.shape, X_train_discrete_features_np.shape
# Out:
# ((10403, 8918), (10403, 8903), (10403, 15))

# %% [markdown]
# # OBTAIN TEST DATA

# %%
X_test  = pd.read_csv(extraction_directory + 'X_test.csv', index_col='id')
X_test_np = X_test.to_numpy()

X_test_periodic = X_test.apply(replicate_row, axis=1)
X_test_periodic_np = X_test_periodic.to_numpy()

X_test_filtered = filter_line(X_test_periodic, ms_flt_array)
X_test_filtered_np = X_test_filtered.to_numpy()

X_test_denoised_np = np.array([process_signal(row, wavelet, level, qrs_band, sampling_rate, dampening)[0:total_length] for row in X_test_filtered_np])
X_test_denoised = pd.DataFrame(data=X_test_denoised_np, columns=X_test.columns, index=X_test.index)

X_test_transformed_np = np.apply_along_axis(normalize_signal, 1, X_test_denoised_np)
X_test_transformed = pd.DataFrame(data=X_test_transformed_np, columns=X_test.columns, index=X_test.index)

X_test_discrete_features_np = np.array([extract_features(row) for row in X_test_transformed_np])

X_test_downsampled_np = X_test_transformed_np[:,:-1:2]
X_test_downsampled = pd.DataFrame(X_test_downsampled_np)

X_test_ready_np = np.concatenate([X_test_downsampled_np, X_test_discrete_features_np], axis=1)
X_test_ready = pd.DataFrame(X_test_ready_np)

# %%
X_train_ready.shape, X_test_ready.shape
# Out:
# ((10403, 8918), (3411, 8918))

# %% [markdown]
# # MODEL TRAINING

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, BatchNormalization, Dropout, Conv1D, Flatten, MaxPooling1D, Input, Concatenate, GlobalAveragePooling1D, Activation
from keras.metrics import AUC
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
import tensorflow as tf
from keras.layers import Input, concatenate
from keras.models import Model
# Out:
# /Users/rcasado/Desktop/Rodrigo_work/Universidad/PhD/Other/Coding/Visual Studio Code/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Convert labels to categorical
y_train_cat_np = to_categorical(y_train_extended.to_numpy())

# Split data
X_train_partial, X_val, y_train_partial, y_val = train_test_split(X_train_ready_np, y_train_cat_np, test_size=0.2, random_state=23)

# %%
learning_rate = 5e-3                            # learning rate of the gradient descent
LAMBD = 3e-3                         # lambda in L2 regularizaion
dropout = 0.3                             # dropout rate
dropout_CNN = .3
dropout_RNN = .3
recurrent_dropout = 0.3

# %%
# CNN part
input_shape_cnn = (X_train_ready_np[:,:-15].shape[1], 1)
cnn_input = Input(shape=input_shape_cnn)
num_discrete_features = X_train_discrete_features_np.shape[1]

x = cnn_input
for _ in range(5):
    x = Conv1D(64, 5, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(dropout_CNN)(x)

x = GlobalAveragePooling1D()(x)

extra_features_input = Input(shape=(num_discrete_features,))

# Combine CNN output and extra features
combined = concatenate([x, extra_features_input])

# FCN part
fc_neurons = [64, 64, 32]
for neurons in fc_neurons:
    combined = Dense(neurons, activation='relu')(combined)
    combined = Dropout(dropout)(combined)

# Output layer
output = Dense(4, activation='softmax')(combined)

# Create the model
model = Model(inputs=[cnn_input, extra_features_input], outputs=output)

# Compile the model
model.compile(loss='categorical_crossentropy',
            optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate),
            metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 8903, 1)]            0         []
#
#  conv1d_5 (Conv1D)           (None, 8903, 64)             384       ['input_3[0][0]']
#
#  max_pooling1d_5 (MaxPoolin  (None, 4451, 64)             0         ['conv1d_5[0][0]']
#  g1D)
#
#  dropout_8 (Dropout)         (None, 4451, 64)             0         ['max_pooling1d_5[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 4451, 64)             20544     ['dropout_8[0][0]']
#
#  max_pooling1d_6 (MaxPoolin  (None, 2225, 64)             0         ['conv1d_6[0][0]']
#  g1D)
#
#  dropout_9 (Dropout)         (None, 2225, 64)             0         ['max_pooling1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 2225, 64)             20544     ['dropout_9[0][0]']
#
#  max_pooling1d_7 (MaxPoolin  (None, 1112, 64)             0         ['conv1d_7[0][0]']
#  g1D)
#
#  dropout_10 (Dropout)        (None, 1112, 64)             0         ['max_pooling1d_7[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 1112, 64)             20544     ['dropout_10[0][0]']
#
#  max_pooling1d_8 (MaxPoolin  (None, 556, 64)              0         ['conv1d_8[0][0]']
#  g1D)
#
#  dropout_11 (Dropout)        (None, 556, 64)              0         ['max_pooling1d_8[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 556, 64)              20544     ['dropout_11[0][0]']
#
#  max_pooling1d_9 (MaxPoolin  (None, 278, 64)              0         ['conv1d_9[0][0]']
#  g1D)
#
#  dropout_12 (Dropout)        (None, 278, 64)              0         ['max_pooling1d_9[0][0]']
#
#  global_average_pooling1d_1  (None, 64)                   0         ['dropout_12[0][0]']
#   (GlobalAveragePooling1D)
#
#  input_4 (InputLayer)        [(None, 15)]                 0         []
#
#  concatenate_1 (Concatenate  (None, 79)                   0         ['global_average_pooling1d_1[0
#  )                                                                  ][0]',
#                                                                      'input_4[0][0]']
#
#  dense_4 (Dense)             (None, 80)                   6400      ['concatenate_1[0][0]']
#
#  dropout_13 (Dropout)        (None, 80)                   0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (None, 64)                   5184      ['dropout_13[0][0]']
#
#  dropout_14 (Dropout)        (None, 64)                   0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 32)                   2080      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 32)                   0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 4)                    132       ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 96356 (376.39 KB)
# Trainable params: 96356 (376.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
start = time.time()
History = model.fit([X_train_partial[:,:-num_discrete_features], X_train_partial[:,-num_discrete_features:]],
                    y_train_partial,
                    epochs=500,
                    batch_size=1024,
                    validation_split=0.0,
                    validation_data=([X_val[:,:-num_discrete_features], X_val[:,-num_discrete_features:]], y_val),
                    shuffle=True,
                    verbose=1)

print('-'*65)
print(f'Training was completed in {time.time() - start:.2f} secs')
print('-'*65)
model.save("model_CNN_with_discrete_features.keras")
# Out:
# Epoch 1/500
# 9/9 [==============================] - 39s 4s/step - loss: 6.8441 - accuracy: 0.2515 - val_loss: 1.3748 - val_accuracy: 0.3018
# Epoch 2/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.6433 - accuracy: 0.2835 - val_loss: 1.3384 - val_accuracy: 0.3729
# Epoch 3/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.3687 - accuracy: 0.3170 - val_loss: 1.3368 - val_accuracy: 0.3253
# Epoch 4/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.3505 - accuracy: 0.3234 - val_loss: 1.3185 - val_accuracy: 0.4056
# Epoch 5/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.3215 - accuracy: 0.3467 - val_loss: 1.2982 - val_accuracy: 0.3335
# Epoch 6/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.3132 - accuracy: 0.3546 - val_loss: 1.2856 - val_accuracy: 0.3575
# Epoch 7/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.3048 - accuracy: 0.3496 - val_loss: 1.2740 - val_accuracy: 0.4051
# Epoch 8/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2877 - accuracy: 0.3623 - val_loss: 1.2511 - val_accuracy: 0.4185
# Epoch 9/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2719 - accuracy: 0.3695 - val_loss: 1.2324 - val_accuracy: 0.4214
# Epoch 10/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2626 - accuracy: 0.3840 - val_loss: 1.2384 - val_accuracy: 0.4094
# Epoch 11/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2521 - accuracy: 0.3874 - val_loss: 1.2126 - val_accuracy: 0.4099
# Epoch 12/500
# 9/9 [==============================] - 36s 4s/step - loss: 1.2459 - accuracy: 0.3957 - val_loss: 1.2498 - val_accuracy: 0.4041
# Epoch 13/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2466 - accuracy: 0.3909 - val_loss: 1.2042 - val_accuracy: 0.4166
# Epoch 14/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2412 - accuracy: 0.3987 - val_loss: 1.2139 - val_accuracy: 0.4205
# Epoch 15/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2236 - accuracy: 0.4084 - val_loss: 1.2030 - val_accuracy: 0.4219
# Epoch 16/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2191 - accuracy: 0.4147 - val_loss: 1.1854 - val_accuracy: 0.4363
# Epoch 17/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.2087 - accuracy: 0.4136 - val_loss: 1.1805 - val_accuracy: 0.4368
# Epoch 18/500
# 9/9 [==============================] - 36s 4s/step - loss: 1.2109 - accuracy: 0.4206 - val_loss: 1.1931 - val_accuracy: 0.4387
# Epoch 19/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1966 - accuracy: 0.4231 - val_loss: 1.1965 - val_accuracy: 0.4224
# Epoch 20/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1826 - accuracy: 0.4366 - val_loss: 1.1561 - val_accuracy: 0.4397
# Epoch 21/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1965 - accuracy: 0.4223 - val_loss: 1.1637 - val_accuracy: 0.4253
# Epoch 22/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1733 - accuracy: 0.4418 - val_loss: 1.1419 - val_accuracy: 0.4589
# Epoch 23/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1500 - accuracy: 0.4535 - val_loss: 1.1982 - val_accuracy: 0.4349
# Epoch 24/500
# 9/9 [==============================] - 247s 4s/step - loss: 1.1384 - accuracy: 0.4572 - val_loss: 1.1668 - val_accuracy: 0.4431
# Epoch 25/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1259 - accuracy: 0.4597 - val_loss: 1.3202 - val_accuracy: 0.4258
# Epoch 26/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.1517 - accuracy: 0.4541 - val_loss: 1.1221 - val_accuracy: 0.4560
# Epoch 27/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.1228 - accuracy: 0.4537 - val_loss: 1.1273 - val_accuracy: 0.4580
# Epoch 28/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0953 - accuracy: 0.4605 - val_loss: 1.0675 - val_accuracy: 0.4738
# Epoch 29/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0819 - accuracy: 0.4761 - val_loss: 1.0715 - val_accuracy: 0.4926
# Epoch 30/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0772 - accuracy: 0.4734 - val_loss: 1.0910 - val_accuracy: 0.4849
# Epoch 31/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0805 - accuracy: 0.4786 - val_loss: 1.0407 - val_accuracy: 0.4897
# Epoch 32/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0810 - accuracy: 0.4876 - val_loss: 1.0935 - val_accuracy: 0.4700
# Epoch 33/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0646 - accuracy: 0.4868 - val_loss: 1.0737 - val_accuracy: 0.4724
# Epoch 34/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0514 - accuracy: 0.4966 - val_loss: 1.0497 - val_accuracy: 0.5017
# Epoch 35/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0462 - accuracy: 0.5064 - val_loss: 1.0292 - val_accuracy: 0.5099
# Epoch 36/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0471 - accuracy: 0.5117 - val_loss: 1.0107 - val_accuracy: 0.5060
# Epoch 37/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0524 - accuracy: 0.5029 - val_loss: 1.0968 - val_accuracy: 0.4921
# Epoch 38/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0560 - accuracy: 0.4888 - val_loss: 1.0452 - val_accuracy: 0.5031
# Epoch 39/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0374 - accuracy: 0.5047 - val_loss: 0.9994 - val_accuracy: 0.5209
# Epoch 40/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0311 - accuracy: 0.5114 - val_loss: 1.0025 - val_accuracy: 0.5060
# Epoch 41/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0281 - accuracy: 0.5101 - val_loss: 1.0574 - val_accuracy: 0.5070
# Epoch 42/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0435 - accuracy: 0.5040 - val_loss: 1.0148 - val_accuracy: 0.5147
# Epoch 43/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0229 - accuracy: 0.5044 - val_loss: 1.0023 - val_accuracy: 0.5113
# Epoch 44/500
# 9/9 [==============================] - 38s 4s/step - loss: 1.0024 - accuracy: 0.5239 - val_loss: 0.9785 - val_accuracy: 0.5382
# Epoch 45/500
# 9/9 [==============================] - 37s 4s/step - loss: 1.0019 - accuracy: 0.5233 - val_loss: 0.9786 - val_accuracy: 0.5478
# Epoch 46/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9927 - accuracy: 0.5382 - val_loss: 0.9878 - val_accuracy: 0.5420
# Epoch 47/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9843 - accuracy: 0.5317 - val_loss: 1.0643 - val_accuracy: 0.5320
# Epoch 48/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9911 - accuracy: 0.5428 - val_loss: 0.9475 - val_accuracy: 0.5521
# Epoch 49/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9774 - accuracy: 0.5413 - val_loss: 0.9983 - val_accuracy: 0.5497
# Epoch 50/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9795 - accuracy: 0.5517 - val_loss: 0.9805 - val_accuracy: 0.5617
# Epoch 51/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9590 - accuracy: 0.5580 - val_loss: 0.9041 - val_accuracy: 0.5733
# Epoch 52/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9789 - accuracy: 0.5499 - val_loss: 1.0160 - val_accuracy: 0.5449
# Epoch 53/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9714 - accuracy: 0.5637 - val_loss: 1.1564 - val_accuracy: 0.4488
# Epoch 54/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9859 - accuracy: 0.5397 - val_loss: 0.9601 - val_accuracy: 0.5738
# Epoch 55/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9527 - accuracy: 0.5591 - val_loss: 0.8908 - val_accuracy: 0.5997
# Epoch 56/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9528 - accuracy: 0.5639 - val_loss: 0.8994 - val_accuracy: 0.6026
# Epoch 57/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.9447 - accuracy: 0.5775 - val_loss: 1.1515 - val_accuracy: 0.5670
# Epoch 58/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.9266 - accuracy: 0.5878 - val_loss: 0.9898 - val_accuracy: 0.5954
# Epoch 59/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.9062 - accuracy: 0.5957 - val_loss: 1.0094 - val_accuracy: 0.5805
# Epoch 60/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.9150 - accuracy: 0.5967 - val_loss: 0.8537 - val_accuracy: 0.6050
# Epoch 61/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.9276 - accuracy: 0.5799 - val_loss: 1.0499 - val_accuracy: 0.5896
# Epoch 62/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.9014 - accuracy: 0.5955 - val_loss: 0.8463 - val_accuracy: 0.6189
# Epoch 63/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8952 - accuracy: 0.6043 - val_loss: 0.9315 - val_accuracy: 0.6108
# Epoch 64/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8944 - accuracy: 0.6055 - val_loss: 1.1110 - val_accuracy: 0.5911
# Epoch 65/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.8802 - accuracy: 0.5987 - val_loss: 0.8235 - val_accuracy: 0.6209
# Epoch 66/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8670 - accuracy: 0.6178 - val_loss: 1.1224 - val_accuracy: 0.5863
# Epoch 67/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.8908 - accuracy: 0.5969 - val_loss: 0.8341 - val_accuracy: 0.6088
# Epoch 68/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8572 - accuracy: 0.6185 - val_loss: 0.8978 - val_accuracy: 0.6180
# Epoch 69/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.8469 - accuracy: 0.6162 - val_loss: 0.8392 - val_accuracy: 0.6358
# Epoch 70/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.8482 - accuracy: 0.6283 - val_loss: 1.0520 - val_accuracy: 0.6103
# Epoch 71/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8419 - accuracy: 0.6192 - val_loss: 0.8070 - val_accuracy: 0.6309
# Epoch 72/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8214 - accuracy: 0.6357 - val_loss: 0.7995 - val_accuracy: 0.6185
# Epoch 73/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8384 - accuracy: 0.6214 - val_loss: 0.7718 - val_accuracy: 0.6516
# Epoch 74/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8195 - accuracy: 0.6404 - val_loss: 1.0216 - val_accuracy: 0.6069
# Epoch 75/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8617 - accuracy: 0.6194 - val_loss: 0.8095 - val_accuracy: 0.6372
# Epoch 76/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8058 - accuracy: 0.6396 - val_loss: 0.7598 - val_accuracy: 0.6473
# Epoch 77/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.8545 - accuracy: 0.6191 - val_loss: 0.7914 - val_accuracy: 0.6583
# Epoch 78/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.8230 - accuracy: 0.6390 - val_loss: 1.0082 - val_accuracy: 0.6338
# Epoch 79/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8156 - accuracy: 0.6405 - val_loss: 0.8240 - val_accuracy: 0.6449
# Epoch 80/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.8009 - accuracy: 0.6456 - val_loss: 0.7542 - val_accuracy: 0.6511
# Epoch 81/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7961 - accuracy: 0.6512 - val_loss: 0.7784 - val_accuracy: 0.6545
# Epoch 82/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7802 - accuracy: 0.6562 - val_loss: 0.7488 - val_accuracy: 0.6588
# Epoch 83/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7895 - accuracy: 0.6620 - val_loss: 0.7617 - val_accuracy: 0.6694
# Epoch 84/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.8117 - accuracy: 0.6449 - val_loss: 0.9440 - val_accuracy: 0.6088
# Epoch 85/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7937 - accuracy: 0.6545 - val_loss: 0.7708 - val_accuracy: 0.6136
# Epoch 86/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.7940 - accuracy: 0.6377 - val_loss: 0.7918 - val_accuracy: 0.6583
# Epoch 87/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7754 - accuracy: 0.6572 - val_loss: 0.9284 - val_accuracy: 0.6055
# Epoch 88/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7678 - accuracy: 0.6609 - val_loss: 0.8199 - val_accuracy: 0.6603
# Epoch 89/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7462 - accuracy: 0.6611 - val_loss: 0.7329 - val_accuracy: 0.6699
# Epoch 90/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7477 - accuracy: 0.6610 - val_loss: 0.8838 - val_accuracy: 0.6074
# Epoch 91/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7664 - accuracy: 0.6578 - val_loss: 0.7204 - val_accuracy: 0.6814
# Epoch 92/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7443 - accuracy: 0.6724 - val_loss: 0.7967 - val_accuracy: 0.6747
# Epoch 93/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7468 - accuracy: 0.6653 - val_loss: 0.7450 - val_accuracy: 0.6603
# Epoch 94/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7348 - accuracy: 0.6789 - val_loss: 0.7664 - val_accuracy: 0.6574
# Epoch 95/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7203 - accuracy: 0.6727 - val_loss: 0.7872 - val_accuracy: 0.6689
# Epoch 96/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7266 - accuracy: 0.6760 - val_loss: 0.8893 - val_accuracy: 0.6564
# Epoch 97/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7359 - accuracy: 0.6659 - val_loss: 0.8197 - val_accuracy: 0.6612
# Epoch 98/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7252 - accuracy: 0.6750 - val_loss: 0.7900 - val_accuracy: 0.6838
# Epoch 99/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7341 - accuracy: 0.6696 - val_loss: 0.7466 - val_accuracy: 0.6559
# Epoch 100/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7391 - accuracy: 0.6733 - val_loss: 0.8247 - val_accuracy: 0.6766
# Epoch 101/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7095 - accuracy: 0.6852 - val_loss: 0.7545 - val_accuracy: 0.6641
# Epoch 102/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7293 - accuracy: 0.6752 - val_loss: 0.6885 - val_accuracy: 0.6833
# Epoch 103/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.7698 - accuracy: 0.6565 - val_loss: 0.7003 - val_accuracy: 0.6862
# Epoch 104/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7417 - accuracy: 0.6667 - val_loss: 0.7187 - val_accuracy: 0.6838
# Epoch 105/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7162 - accuracy: 0.6764 - val_loss: 0.8127 - val_accuracy: 0.6598
# Epoch 106/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7071 - accuracy: 0.6896 - val_loss: 0.9187 - val_accuracy: 0.6545
# Epoch 107/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.7248 - accuracy: 0.6832 - val_loss: 0.7792 - val_accuracy: 0.6511
# Epoch 108/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7380 - accuracy: 0.6769 - val_loss: 0.7077 - val_accuracy: 0.6997
# Epoch 109/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.7124 - accuracy: 0.6835 - val_loss: 0.7216 - val_accuracy: 0.6953
# Epoch 110/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7067 - accuracy: 0.6788 - val_loss: 0.7572 - val_accuracy: 0.6631
# Epoch 111/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6965 - accuracy: 0.6950 - val_loss: 0.7051 - val_accuracy: 0.6627
# Epoch 112/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.8427 - accuracy: 0.6299 - val_loss: 0.7486 - val_accuracy: 0.6901
# Epoch 113/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.7627 - accuracy: 0.6580 - val_loss: 0.7305 - val_accuracy: 0.6723
# Epoch 114/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7263 - accuracy: 0.6786 - val_loss: 0.7663 - val_accuracy: 0.6747
# Epoch 115/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.7131 - accuracy: 0.6825 - val_loss: 0.7406 - val_accuracy: 0.6915
# Epoch 116/500
# 9/9 [==============================] - 40s 4s/step - loss: 0.7082 - accuracy: 0.6834 - val_loss: 0.9907 - val_accuracy: 0.6458
# Epoch 117/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.7030 - accuracy: 0.6878 - val_loss: 0.7529 - val_accuracy: 0.6905
# Epoch 118/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6853 - accuracy: 0.6929 - val_loss: 0.8625 - val_accuracy: 0.6660
# Epoch 119/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.6899 - accuracy: 0.6893 - val_loss: 0.7571 - val_accuracy: 0.6958
# Epoch 120/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6806 - accuracy: 0.6957 - val_loss: 0.7280 - val_accuracy: 0.6824
# Epoch 121/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6821 - accuracy: 0.7055 - val_loss: 0.8430 - val_accuracy: 0.6723
# Epoch 122/500
# 9/9 [==============================] - 40s 4s/step - loss: 0.6851 - accuracy: 0.6965 - val_loss: 0.6509 - val_accuracy: 0.7040
# Epoch 123/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.7242 - accuracy: 0.6834 - val_loss: 0.7289 - val_accuracy: 0.6785
# Epoch 124/500
# 9/9 [==============================] - 40s 4s/step - loss: 0.6978 - accuracy: 0.6941 - val_loss: 0.7229 - val_accuracy: 0.6737
# Epoch 125/500
# 9/9 [==============================] - 40s 4s/step - loss: 0.6738 - accuracy: 0.7016 - val_loss: 0.7121 - val_accuracy: 0.6982
# Epoch 126/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6664 - accuracy: 0.7087 - val_loss: 0.7790 - val_accuracy: 0.6939
# Epoch 127/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6603 - accuracy: 0.7098 - val_loss: 0.7200 - val_accuracy: 0.7016
# Epoch 128/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6604 - accuracy: 0.7091 - val_loss: 0.7402 - val_accuracy: 0.6949
# Epoch 129/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.6428 - accuracy: 0.7181 - val_loss: 0.7246 - val_accuracy: 0.7040
# Epoch 130/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6529 - accuracy: 0.7103 - val_loss: 0.7364 - val_accuracy: 0.7016
# Epoch 131/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6634 - accuracy: 0.7086 - val_loss: 0.7441 - val_accuracy: 0.7035
# Epoch 132/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.6676 - accuracy: 0.7049 - val_loss: 0.7324 - val_accuracy: 0.6968
# Epoch 133/500
# 9/9 [==============================] - 39s 4s/step - loss: 0.6574 - accuracy: 0.7106 - val_loss: 0.6854 - val_accuracy: 0.6987
# Epoch 134/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6601 - accuracy: 0.7079 - val_loss: 0.7870 - val_accuracy: 0.6747
# Epoch 135/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6551 - accuracy: 0.7176 - val_loss: 0.9180 - val_accuracy: 0.6655
# Epoch 136/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.6859 - accuracy: 0.6986 - val_loss: 0.7086 - val_accuracy: 0.7035
# Epoch 137/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6700 - accuracy: 0.6989 - val_loss: 0.7571 - val_accuracy: 0.6708
# Epoch 138/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6439 - accuracy: 0.7164 - val_loss: 0.7184 - val_accuracy: 0.6973
# Epoch 139/500
# 9/9 [==============================] - 53s 6s/step - loss: 0.6409 - accuracy: 0.7187 - val_loss: 0.7625 - val_accuracy: 0.6910
# Epoch 140/500
# 9/9 [==============================] - 56s 6s/step - loss: 0.6282 - accuracy: 0.7247 - val_loss: 0.6616 - val_accuracy: 0.7208
# Epoch 141/500
# 9/9 [==============================] - 56s 6s/step - loss: 0.6398 - accuracy: 0.7206 - val_loss: 0.7062 - val_accuracy: 0.7011
# Epoch 142/500
# 9/9 [==============================] - 53s 6s/step - loss: 0.6288 - accuracy: 0.7205 - val_loss: 0.6928 - val_accuracy: 0.7218
# Epoch 143/500
# 9/9 [==============================] - 57s 6s/step - loss: 0.6444 - accuracy: 0.7181 - val_loss: 0.6416 - val_accuracy: 0.7251
# Epoch 144/500
# 9/9 [==============================] - 58s 6s/step - loss: 0.6334 - accuracy: 0.7224 - val_loss: 0.6339 - val_accuracy: 0.7247
# Epoch 145/500
# 9/9 [==============================] - 58s 6s/step - loss: 0.6601 - accuracy: 0.7081 - val_loss: 0.6973 - val_accuracy: 0.7001
# Epoch 146/500
# 9/9 [==============================] - 57s 6s/step - loss: 0.6421 - accuracy: 0.7265 - val_loss: 0.6465 - val_accuracy: 0.7251
# Epoch 147/500
# 9/9 [==============================] - 55s 6s/step - loss: 0.6405 - accuracy: 0.7261 - val_loss: 0.7592 - val_accuracy: 0.7006
# Epoch 148/500
# 9/9 [==============================] - 54s 6s/step - loss: 0.6323 - accuracy: 0.7216 - val_loss: 0.9191 - val_accuracy: 0.6271
# Epoch 149/500
# 9/9 [==============================] - 384s 6s/step - loss: 0.6584 - accuracy: 0.7126 - val_loss: 0.6570 - val_accuracy: 0.7242
# Epoch 150/500
# 9/9 [==============================] - 46s 5s/step - loss: 0.6341 - accuracy: 0.7235 - val_loss: 0.7341 - val_accuracy: 0.7102
# Epoch 151/500
# 9/9 [==============================] - 60s 7s/step - loss: 0.6229 - accuracy: 0.7380 - val_loss: 0.6527 - val_accuracy: 0.7237
# Epoch 152/500
# 9/9 [==============================] - 54s 6s/step - loss: 0.6289 - accuracy: 0.7293 - val_loss: 1.2046 - val_accuracy: 0.6108
# Epoch 153/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.7618 - accuracy: 0.6822 - val_loss: 0.6874 - val_accuracy: 0.7074
# Epoch 154/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.7090 - accuracy: 0.6893 - val_loss: 0.6753 - val_accuracy: 0.7232
# Epoch 155/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6431 - accuracy: 0.7233 - val_loss: 0.7032 - val_accuracy: 0.6934
# Epoch 156/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6504 - accuracy: 0.7185 - val_loss: 0.6369 - val_accuracy: 0.7146
# Epoch 157/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6234 - accuracy: 0.7280 - val_loss: 0.6476 - val_accuracy: 0.7261
# Epoch 158/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6172 - accuracy: 0.7265 - val_loss: 0.6375 - val_accuracy: 0.7285
# Epoch 159/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6106 - accuracy: 0.7394 - val_loss: 0.6631 - val_accuracy: 0.7088
# Epoch 160/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6441 - accuracy: 0.7235 - val_loss: 0.6229 - val_accuracy: 0.7218
# Epoch 161/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6216 - accuracy: 0.7366 - val_loss: 0.6497 - val_accuracy: 0.7391
# Epoch 162/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.6027 - accuracy: 0.7459 - val_loss: 0.5994 - val_accuracy: 0.7468
# Epoch 163/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5958 - accuracy: 0.7540 - val_loss: 0.6891 - val_accuracy: 0.7242
# Epoch 164/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6076 - accuracy: 0.7391 - val_loss: 0.6523 - val_accuracy: 0.7448
# Epoch 165/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.6014 - accuracy: 0.7419 - val_loss: 0.7244 - val_accuracy: 0.7198
# Epoch 166/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5968 - accuracy: 0.7480 - val_loss: 0.7978 - val_accuracy: 0.6747
# Epoch 167/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.6141 - accuracy: 0.7323 - val_loss: 0.6311 - val_accuracy: 0.7420
# Epoch 168/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6017 - accuracy: 0.7461 - val_loss: 0.6126 - val_accuracy: 0.7516
# Epoch 169/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6132 - accuracy: 0.7445 - val_loss: 0.6581 - val_accuracy: 0.7371
# Epoch 170/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5810 - accuracy: 0.7584 - val_loss: 0.7237 - val_accuracy: 0.7208
# Epoch 171/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5858 - accuracy: 0.7495 - val_loss: 0.7173 - val_accuracy: 0.7069
# Epoch 172/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5940 - accuracy: 0.7465 - val_loss: 0.5926 - val_accuracy: 0.7477
# Epoch 173/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6024 - accuracy: 0.7480 - val_loss: 0.5912 - val_accuracy: 0.7636
# Epoch 174/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6066 - accuracy: 0.7420 - val_loss: 0.6952 - val_accuracy: 0.7126
# Epoch 175/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6151 - accuracy: 0.7431 - val_loss: 0.6398 - val_accuracy: 0.7174
# Epoch 176/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6010 - accuracy: 0.7453 - val_loss: 0.5843 - val_accuracy: 0.7593
# Epoch 177/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5893 - accuracy: 0.7586 - val_loss: 0.8501 - val_accuracy: 0.6598
# Epoch 178/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5925 - accuracy: 0.7478 - val_loss: 0.6408 - val_accuracy: 0.7472
# Epoch 179/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5734 - accuracy: 0.7594 - val_loss: 0.6026 - val_accuracy: 0.7487
# Epoch 180/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5737 - accuracy: 0.7611 - val_loss: 0.6549 - val_accuracy: 0.7232
# Epoch 181/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5736 - accuracy: 0.7706 - val_loss: 0.6835 - val_accuracy: 0.7343
# Epoch 182/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5632 - accuracy: 0.7700 - val_loss: 0.5658 - val_accuracy: 0.7568
# Epoch 183/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5683 - accuracy: 0.7680 - val_loss: 0.5875 - val_accuracy: 0.7535
# Epoch 184/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5799 - accuracy: 0.7614 - val_loss: 0.8368 - val_accuracy: 0.6795
# Epoch 185/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.6082 - accuracy: 0.7433 - val_loss: 0.5756 - val_accuracy: 0.7511
# Epoch 186/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5827 - accuracy: 0.7594 - val_loss: 0.5733 - val_accuracy: 0.7540
# Epoch 187/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5728 - accuracy: 0.7664 - val_loss: 0.5824 - val_accuracy: 0.7429
# Epoch 188/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5752 - accuracy: 0.7616 - val_loss: 0.6694 - val_accuracy: 0.7295
# Epoch 189/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5660 - accuracy: 0.7641 - val_loss: 0.5858 - val_accuracy: 0.7487
# Epoch 190/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5665 - accuracy: 0.7698 - val_loss: 0.6405 - val_accuracy: 0.7357
# Epoch 191/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5649 - accuracy: 0.7692 - val_loss: 0.8207 - val_accuracy: 0.6896
# Epoch 192/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5793 - accuracy: 0.7614 - val_loss: 0.5500 - val_accuracy: 0.7713
# Epoch 193/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5727 - accuracy: 0.7674 - val_loss: 0.8284 - val_accuracy: 0.6675
# Epoch 194/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5876 - accuracy: 0.7622 - val_loss: 0.5671 - val_accuracy: 0.7770
# Epoch 195/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5594 - accuracy: 0.7754 - val_loss: 0.7285 - val_accuracy: 0.7271
# Epoch 196/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5581 - accuracy: 0.7823 - val_loss: 0.6455 - val_accuracy: 0.7280
# Epoch 197/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.6177 - accuracy: 0.7492 - val_loss: 0.6088 - val_accuracy: 0.7290
# Epoch 198/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5825 - accuracy: 0.7618 - val_loss: 0.8055 - val_accuracy: 0.7016
# Epoch 199/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5667 - accuracy: 0.7668 - val_loss: 0.5545 - val_accuracy: 0.7602
# Epoch 200/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5636 - accuracy: 0.7728 - val_loss: 0.6889 - val_accuracy: 0.7314
# Epoch 201/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5399 - accuracy: 0.7796 - val_loss: 0.5776 - val_accuracy: 0.7520
# Epoch 202/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5339 - accuracy: 0.7843 - val_loss: 0.5961 - val_accuracy: 0.7544
# Epoch 203/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5396 - accuracy: 0.7823 - val_loss: 0.6882 - val_accuracy: 0.7275
# Epoch 204/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5409 - accuracy: 0.7791 - val_loss: 0.5903 - val_accuracy: 0.7544
# Epoch 205/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5401 - accuracy: 0.7800 - val_loss: 0.5770 - val_accuracy: 0.7751
# Epoch 206/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5501 - accuracy: 0.7737 - val_loss: 0.6865 - val_accuracy: 0.7338
# Epoch 207/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5513 - accuracy: 0.7794 - val_loss: 0.6956 - val_accuracy: 0.7362
# Epoch 208/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5607 - accuracy: 0.7728 - val_loss: 0.7139 - val_accuracy: 0.7295
# Epoch 209/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5413 - accuracy: 0.7743 - val_loss: 0.5668 - val_accuracy: 0.7655
# Epoch 210/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5569 - accuracy: 0.7705 - val_loss: 0.7222 - val_accuracy: 0.7333
# Epoch 211/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5597 - accuracy: 0.7737 - val_loss: 0.6002 - val_accuracy: 0.7501
# Epoch 212/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5674 - accuracy: 0.7760 - val_loss: 0.5389 - val_accuracy: 0.7732
# Epoch 213/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5646 - accuracy: 0.7770 - val_loss: 0.6515 - val_accuracy: 0.7424
# Epoch 214/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5483 - accuracy: 0.7794 - val_loss: 0.5875 - val_accuracy: 0.7617
# Epoch 215/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5322 - accuracy: 0.7882 - val_loss: 0.5820 - val_accuracy: 0.7511
# Epoch 216/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5222 - accuracy: 0.7908 - val_loss: 0.5538 - val_accuracy: 0.7626
# Epoch 217/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5179 - accuracy: 0.7912 - val_loss: 0.5579 - val_accuracy: 0.7746
# Epoch 218/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5499 - accuracy: 0.7809 - val_loss: 0.5869 - val_accuracy: 0.7511
# Epoch 219/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5669 - accuracy: 0.7701 - val_loss: 0.5773 - val_accuracy: 0.7535
# Epoch 220/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5565 - accuracy: 0.7761 - val_loss: 0.5694 - val_accuracy: 0.7602
# Epoch 221/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5373 - accuracy: 0.7761 - val_loss: 0.6279 - val_accuracy: 0.7511
# Epoch 222/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5229 - accuracy: 0.7867 - val_loss: 0.5919 - val_accuracy: 0.7621
# Epoch 223/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5336 - accuracy: 0.7891 - val_loss: 0.5252 - val_accuracy: 0.7785
# Epoch 224/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5510 - accuracy: 0.7797 - val_loss: 0.8564 - val_accuracy: 0.6819
# Epoch 225/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5892 - accuracy: 0.7628 - val_loss: 0.5813 - val_accuracy: 0.7679
# Epoch 226/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5577 - accuracy: 0.7727 - val_loss: 0.6067 - val_accuracy: 0.7448
# Epoch 227/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5283 - accuracy: 0.7894 - val_loss: 0.6033 - val_accuracy: 0.7631
# Epoch 228/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5586 - accuracy: 0.7843 - val_loss: 0.6339 - val_accuracy: 0.7299
# Epoch 229/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5657 - accuracy: 0.7705 - val_loss: 0.5409 - val_accuracy: 0.7746
# Epoch 230/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5599 - accuracy: 0.7722 - val_loss: 0.5849 - val_accuracy: 0.7607
# Epoch 231/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5575 - accuracy: 0.7777 - val_loss: 0.6464 - val_accuracy: 0.7328
# Epoch 232/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5313 - accuracy: 0.7849 - val_loss: 0.5300 - val_accuracy: 0.7838
# Epoch 233/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5346 - accuracy: 0.7847 - val_loss: 0.5621 - val_accuracy: 0.7708
# Epoch 234/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5653 - accuracy: 0.7784 - val_loss: 0.7260 - val_accuracy: 0.6886
# Epoch 235/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5946 - accuracy: 0.7656 - val_loss: 0.6380 - val_accuracy: 0.7487
# Epoch 236/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5333 - accuracy: 0.7888 - val_loss: 0.5713 - val_accuracy: 0.7617
# Epoch 237/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5115 - accuracy: 0.7955 - val_loss: 0.5895 - val_accuracy: 0.7607
# Epoch 238/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5100 - accuracy: 0.7976 - val_loss: 0.5742 - val_accuracy: 0.7607
# Epoch 239/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5007 - accuracy: 0.7982 - val_loss: 0.5590 - val_accuracy: 0.7626
# Epoch 240/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4921 - accuracy: 0.8052 - val_loss: 0.5497 - val_accuracy: 0.7785
# Epoch 241/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5038 - accuracy: 0.8014 - val_loss: 0.5562 - val_accuracy: 0.7722
# Epoch 242/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4937 - accuracy: 0.8052 - val_loss: 0.5556 - val_accuracy: 0.7693
# Epoch 243/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5164 - accuracy: 0.7934 - val_loss: 0.5587 - val_accuracy: 0.7693
# Epoch 244/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4962 - accuracy: 0.8002 - val_loss: 0.5377 - val_accuracy: 0.7761
# Epoch 245/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5156 - accuracy: 0.7949 - val_loss: 0.6572 - val_accuracy: 0.7347
# Epoch 246/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5222 - accuracy: 0.7928 - val_loss: 0.5551 - val_accuracy: 0.7785
# Epoch 247/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5178 - accuracy: 0.7962 - val_loss: 0.5296 - val_accuracy: 0.7689
# Epoch 248/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4908 - accuracy: 0.8053 - val_loss: 0.5760 - val_accuracy: 0.7588
# Epoch 249/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4937 - accuracy: 0.8050 - val_loss: 0.5637 - val_accuracy: 0.7631
# Epoch 250/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4846 - accuracy: 0.8086 - val_loss: 0.6326 - val_accuracy: 0.7520
# Epoch 251/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5042 - accuracy: 0.8006 - val_loss: 0.5329 - val_accuracy: 0.7866
# Epoch 252/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4967 - accuracy: 0.8061 - val_loss: 0.5749 - val_accuracy: 0.7617
# Epoch 253/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5101 - accuracy: 0.7992 - val_loss: 0.5772 - val_accuracy: 0.7530
# Epoch 254/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4960 - accuracy: 0.8040 - val_loss: 0.6218 - val_accuracy: 0.7564
# Epoch 255/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4918 - accuracy: 0.8106 - val_loss: 0.5334 - val_accuracy: 0.7833
# Epoch 256/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4899 - accuracy: 0.8109 - val_loss: 0.4965 - val_accuracy: 0.7929
# Epoch 257/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5449 - accuracy: 0.7813 - val_loss: 0.6688 - val_accuracy: 0.7155
# Epoch 258/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5339 - accuracy: 0.7826 - val_loss: 0.5479 - val_accuracy: 0.7823
# Epoch 259/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4995 - accuracy: 0.7991 - val_loss: 0.5166 - val_accuracy: 0.7881
# Epoch 260/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4776 - accuracy: 0.8094 - val_loss: 0.5984 - val_accuracy: 0.7535
# Epoch 261/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4822 - accuracy: 0.8101 - val_loss: 0.5470 - val_accuracy: 0.7847
# Epoch 262/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4826 - accuracy: 0.8086 - val_loss: 0.5680 - val_accuracy: 0.7722
# Epoch 263/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4721 - accuracy: 0.8130 - val_loss: 0.5381 - val_accuracy: 0.7722
# Epoch 264/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5130 - accuracy: 0.7914 - val_loss: 0.5776 - val_accuracy: 0.7593
# Epoch 265/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5062 - accuracy: 0.7969 - val_loss: 0.5060 - val_accuracy: 0.7905
# Epoch 266/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4928 - accuracy: 0.8047 - val_loss: 0.6439 - val_accuracy: 0.7496
# Epoch 267/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4900 - accuracy: 0.8025 - val_loss: 0.6474 - val_accuracy: 0.7439
# Epoch 268/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4853 - accuracy: 0.8053 - val_loss: 0.5138 - val_accuracy: 0.7943
# Epoch 269/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4861 - accuracy: 0.8098 - val_loss: 0.5341 - val_accuracy: 0.7765
# Epoch 270/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4978 - accuracy: 0.8016 - val_loss: 0.5448 - val_accuracy: 0.7693
# Epoch 271/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4844 - accuracy: 0.8095 - val_loss: 0.5941 - val_accuracy: 0.7463
# Epoch 272/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4856 - accuracy: 0.8028 - val_loss: 0.5466 - val_accuracy: 0.7804
# Epoch 273/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4830 - accuracy: 0.8110 - val_loss: 0.5143 - val_accuracy: 0.7833
# Epoch 274/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4905 - accuracy: 0.8047 - val_loss: 0.5523 - val_accuracy: 0.7655
# Epoch 275/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4733 - accuracy: 0.8107 - val_loss: 0.5095 - val_accuracy: 0.7862
# Epoch 276/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4605 - accuracy: 0.8170 - val_loss: 0.5320 - val_accuracy: 0.7790
# Epoch 277/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4701 - accuracy: 0.8189 - val_loss: 0.5925 - val_accuracy: 0.7717
# Epoch 278/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4662 - accuracy: 0.8136 - val_loss: 0.5359 - val_accuracy: 0.7722
# Epoch 279/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4899 - accuracy: 0.8055 - val_loss: 0.5610 - val_accuracy: 0.7790
# Epoch 280/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4868 - accuracy: 0.8083 - val_loss: 0.5366 - val_accuracy: 0.7785
# Epoch 281/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4691 - accuracy: 0.8152 - val_loss: 0.5764 - val_accuracy: 0.7770
# Epoch 282/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4956 - accuracy: 0.8101 - val_loss: 0.5232 - val_accuracy: 0.7794
# Epoch 283/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4680 - accuracy: 0.8198 - val_loss: 0.4892 - val_accuracy: 0.8035
# Epoch 284/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4631 - accuracy: 0.8159 - val_loss: 0.6466 - val_accuracy: 0.7415
# Epoch 285/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4708 - accuracy: 0.8104 - val_loss: 0.5545 - val_accuracy: 0.7814
# Epoch 286/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4586 - accuracy: 0.8229 - val_loss: 0.5077 - val_accuracy: 0.7967
# Epoch 287/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4610 - accuracy: 0.8235 - val_loss: 0.5050 - val_accuracy: 0.7963
# Epoch 288/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4841 - accuracy: 0.8142 - val_loss: 0.7664 - val_accuracy: 0.6824
# Epoch 289/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5103 - accuracy: 0.8004 - val_loss: 0.4976 - val_accuracy: 0.7881
# Epoch 290/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4854 - accuracy: 0.8147 - val_loss: 0.5212 - val_accuracy: 0.7900
# Epoch 291/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4818 - accuracy: 0.8140 - val_loss: 0.5453 - val_accuracy: 0.7689
# Epoch 292/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4839 - accuracy: 0.8131 - val_loss: 0.5111 - val_accuracy: 0.7761
# Epoch 293/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4742 - accuracy: 0.8125 - val_loss: 0.5736 - val_accuracy: 0.7765
# Epoch 294/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4697 - accuracy: 0.8196 - val_loss: 0.6229 - val_accuracy: 0.7746
# Epoch 295/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4587 - accuracy: 0.8147 - val_loss: 0.5635 - val_accuracy: 0.7833
# Epoch 296/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4688 - accuracy: 0.8151 - val_loss: 0.4838 - val_accuracy: 0.7934
# Epoch 297/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5016 - accuracy: 0.8023 - val_loss: 0.5450 - val_accuracy: 0.7732
# Epoch 298/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5306 - accuracy: 0.7950 - val_loss: 0.6022 - val_accuracy: 0.7631
# Epoch 299/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5094 - accuracy: 0.7973 - val_loss: 0.5258 - val_accuracy: 0.7967
# Epoch 300/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4848 - accuracy: 0.8125 - val_loss: 0.4766 - val_accuracy: 0.8030
# Epoch 301/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5159 - accuracy: 0.7996 - val_loss: 0.5035 - val_accuracy: 0.8001
# Epoch 302/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4850 - accuracy: 0.8128 - val_loss: 0.5300 - val_accuracy: 0.7963
# Epoch 303/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4775 - accuracy: 0.8166 - val_loss: 0.5835 - val_accuracy: 0.7708
# Epoch 304/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4793 - accuracy: 0.8091 - val_loss: 0.5358 - val_accuracy: 0.7765
# Epoch 305/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4679 - accuracy: 0.8180 - val_loss: 0.5325 - val_accuracy: 0.7886
# Epoch 306/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4474 - accuracy: 0.8272 - val_loss: 0.4968 - val_accuracy: 0.8035
# Epoch 307/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4570 - accuracy: 0.8178 - val_loss: 0.5287 - val_accuracy: 0.7847
# Epoch 308/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4300 - accuracy: 0.8298 - val_loss: 0.5105 - val_accuracy: 0.8015
# Epoch 309/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4351 - accuracy: 0.8262 - val_loss: 0.5617 - val_accuracy: 0.7756
# Epoch 310/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4600 - accuracy: 0.8155 - val_loss: 0.4930 - val_accuracy: 0.8001
# Epoch 311/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4439 - accuracy: 0.8295 - val_loss: 0.4684 - val_accuracy: 0.8087
# Epoch 312/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4329 - accuracy: 0.8363 - val_loss: 0.5413 - val_accuracy: 0.7900
# Epoch 313/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4311 - accuracy: 0.8379 - val_loss: 0.4665 - val_accuracy: 0.8203
# Epoch 314/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.4416 - accuracy: 0.8323 - val_loss: 0.5364 - val_accuracy: 0.7910
# Epoch 315/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4324 - accuracy: 0.8347 - val_loss: 0.5673 - val_accuracy: 0.7804
# Epoch 316/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4515 - accuracy: 0.8220 - val_loss: 0.5149 - val_accuracy: 0.7938
# Epoch 317/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4379 - accuracy: 0.8270 - val_loss: 0.4767 - val_accuracy: 0.8059
# Epoch 318/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4340 - accuracy: 0.8337 - val_loss: 0.4968 - val_accuracy: 0.7953
# Epoch 319/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4358 - accuracy: 0.8338 - val_loss: 0.4909 - val_accuracy: 0.8111
# Epoch 320/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4844 - accuracy: 0.8112 - val_loss: 0.5532 - val_accuracy: 0.7847
# Epoch 321/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4621 - accuracy: 0.8236 - val_loss: 0.5263 - val_accuracy: 0.7924
# Epoch 322/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4490 - accuracy: 0.8260 - val_loss: 0.4632 - val_accuracy: 0.8111
# Epoch 323/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4296 - accuracy: 0.8331 - val_loss: 0.5520 - val_accuracy: 0.7818
# Epoch 324/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4352 - accuracy: 0.8294 - val_loss: 0.4782 - val_accuracy: 0.8111
# Epoch 325/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4654 - accuracy: 0.8178 - val_loss: 0.5521 - val_accuracy: 0.7818
# Epoch 326/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4573 - accuracy: 0.8188 - val_loss: 0.5431 - val_accuracy: 0.7833
# Epoch 327/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.4499 - accuracy: 0.8242 - val_loss: 0.5241 - val_accuracy: 0.7881
# Epoch 328/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4646 - accuracy: 0.8158 - val_loss: 0.5598 - val_accuracy: 0.7799
# Epoch 329/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4552 - accuracy: 0.8265 - val_loss: 0.5316 - val_accuracy: 0.7852
# Epoch 330/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4496 - accuracy: 0.8271 - val_loss: 0.5430 - val_accuracy: 0.7814
# Epoch 331/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4595 - accuracy: 0.8283 - val_loss: 0.4868 - val_accuracy: 0.7943
# Epoch 332/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4582 - accuracy: 0.8262 - val_loss: 0.4797 - val_accuracy: 0.8006
# Epoch 333/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4607 - accuracy: 0.8171 - val_loss: 0.5000 - val_accuracy: 0.8025
# Epoch 334/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.4431 - accuracy: 0.8248 - val_loss: 0.5338 - val_accuracy: 0.7857
# Epoch 335/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4400 - accuracy: 0.8242 - val_loss: 0.4660 - val_accuracy: 0.8121
# Epoch 336/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4483 - accuracy: 0.8235 - val_loss: 0.4970 - val_accuracy: 0.8092
# Epoch 337/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4450 - accuracy: 0.8285 - val_loss: 0.5353 - val_accuracy: 0.7862
# Epoch 338/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4335 - accuracy: 0.8295 - val_loss: 0.4938 - val_accuracy: 0.7924
# Epoch 339/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4749 - accuracy: 0.8202 - val_loss: 0.5225 - val_accuracy: 0.7871
# Epoch 340/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4610 - accuracy: 0.8206 - val_loss: 0.6443 - val_accuracy: 0.7607
# Epoch 341/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4639 - accuracy: 0.8154 - val_loss: 0.5358 - val_accuracy: 0.8020
# Epoch 342/500
# ...
# Epoch 389/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4018 - accuracy: 0.8398 - val_loss: 0.4469 - val_accuracy: 0.8140
# Epoch 390/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4063 - accuracy: 0.8462 - val_loss: 0.4575 - val_accuracy: 0.8198
# Epoch 391/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4032 - accuracy: 0.8426 - val_loss: 0.4712 - val_accuracy: 0.8097
# Epoch 392/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3926 - accuracy: 0.8462 - val_loss: 0.4693 - val_accuracy: 0.8111
# Epoch 393/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3921 - accuracy: 0.8499 - val_loss: 0.5393 - val_accuracy: 0.8011
# Epoch 394/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4486 - accuracy: 0.8284 - val_loss: 0.4787 - val_accuracy: 0.8083
# Epoch 395/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4343 - accuracy: 0.8343 - val_loss: 0.5308 - val_accuracy: 0.7823
# Epoch 396/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4232 - accuracy: 0.8362 - val_loss: 0.5148 - val_accuracy: 0.7972
# Epoch 397/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4125 - accuracy: 0.8397 - val_loss: 0.5335 - val_accuracy: 0.7953
# Epoch 398/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.5029 - accuracy: 0.8243 - val_loss: 0.4837 - val_accuracy: 0.8083
# Epoch 399/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.5151 - accuracy: 0.8063 - val_loss: 0.5278 - val_accuracy: 0.8006
# Epoch 400/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4539 - accuracy: 0.8249 - val_loss: 0.5144 - val_accuracy: 0.7900
# Epoch 401/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4266 - accuracy: 0.8374 - val_loss: 0.5054 - val_accuracy: 0.8001
# Epoch 402/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4394 - accuracy: 0.8314 - val_loss: 0.4596 - val_accuracy: 0.8174
# Epoch 403/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4147 - accuracy: 0.8381 - val_loss: 0.4809 - val_accuracy: 0.8006
# Epoch 404/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4064 - accuracy: 0.8435 - val_loss: 0.4444 - val_accuracy: 0.8294
# Epoch 405/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4165 - accuracy: 0.8399 - val_loss: 0.4954 - val_accuracy: 0.8063
# Epoch 406/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4142 - accuracy: 0.8372 - val_loss: 0.4844 - val_accuracy: 0.7972
# Epoch 407/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4208 - accuracy: 0.8326 - val_loss: 0.4867 - val_accuracy: 0.8092
# Epoch 408/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4007 - accuracy: 0.8449 - val_loss: 0.4831 - val_accuracy: 0.8044
# Epoch 409/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3856 - accuracy: 0.8491 - val_loss: 0.4887 - val_accuracy: 0.8092
# Epoch 410/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3885 - accuracy: 0.8500 - val_loss: 0.4964 - val_accuracy: 0.8087
# Epoch 411/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3945 - accuracy: 0.8503 - val_loss: 0.4828 - val_accuracy: 0.8025
# Epoch 412/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4009 - accuracy: 0.8494 - val_loss: 0.5813 - val_accuracy: 0.7751
# Epoch 413/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4271 - accuracy: 0.8379 - val_loss: 0.4619 - val_accuracy: 0.8092
# Epoch 414/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4217 - accuracy: 0.8374 - val_loss: 0.4252 - val_accuracy: 0.8294
# Epoch 415/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4096 - accuracy: 0.8423 - val_loss: 0.4560 - val_accuracy: 0.8188
# Epoch 416/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3931 - accuracy: 0.8456 - val_loss: 0.4364 - val_accuracy: 0.8284
# Epoch 417/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3824 - accuracy: 0.8530 - val_loss: 0.5039 - val_accuracy: 0.7938
# Epoch 418/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3960 - accuracy: 0.8468 - val_loss: 0.5293 - val_accuracy: 0.7924
# Epoch 419/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4055 - accuracy: 0.8438 - val_loss: 0.4566 - val_accuracy: 0.8212
# Epoch 420/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3843 - accuracy: 0.8515 - val_loss: 0.4804 - val_accuracy: 0.8111
# Epoch 421/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3981 - accuracy: 0.8479 - val_loss: 0.5398 - val_accuracy: 0.7818
# Epoch 422/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3970 - accuracy: 0.8523 - val_loss: 0.5332 - val_accuracy: 0.8020
# Epoch 423/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3944 - accuracy: 0.8492 - val_loss: 0.4774 - val_accuracy: 0.8155
# Epoch 424/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3928 - accuracy: 0.8496 - val_loss: 0.5166 - val_accuracy: 0.7991
# Epoch 425/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3951 - accuracy: 0.8463 - val_loss: 0.4947 - val_accuracy: 0.8015
# Epoch 426/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4130 - accuracy: 0.8423 - val_loss: 0.4426 - val_accuracy: 0.8174
# Epoch 427/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4078 - accuracy: 0.8433 - val_loss: 0.5672 - val_accuracy: 0.7852
# Epoch 428/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4649 - accuracy: 0.8241 - val_loss: 0.4962 - val_accuracy: 0.7833
# Epoch 429/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4377 - accuracy: 0.8317 - val_loss: 0.5510 - val_accuracy: 0.7895
# Epoch 430/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4145 - accuracy: 0.8415 - val_loss: 0.5139 - val_accuracy: 0.7938
# Epoch 431/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3910 - accuracy: 0.8467 - val_loss: 0.4826 - val_accuracy: 0.8121
# Epoch 432/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3783 - accuracy: 0.8546 - val_loss: 0.4812 - val_accuracy: 0.8068
# Epoch 433/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3887 - accuracy: 0.8491 - val_loss: 0.5276 - val_accuracy: 0.7938
# Epoch 434/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4148 - accuracy: 0.8348 - val_loss: 0.4731 - val_accuracy: 0.8121
# Epoch 435/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3934 - accuracy: 0.8444 - val_loss: 0.5088 - val_accuracy: 0.8111
# Epoch 436/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4021 - accuracy: 0.8487 - val_loss: 0.4478 - val_accuracy: 0.8284
# Epoch 437/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3888 - accuracy: 0.8518 - val_loss: 0.4586 - val_accuracy: 0.8184
# Epoch 438/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3823 - accuracy: 0.8520 - val_loss: 0.4546 - val_accuracy: 0.8188
# Epoch 439/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3744 - accuracy: 0.8545 - val_loss: 0.5413 - val_accuracy: 0.7895
# Epoch 440/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3913 - accuracy: 0.8511 - val_loss: 0.4816 - val_accuracy: 0.8092
# Epoch 441/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3863 - accuracy: 0.8499 - val_loss: 0.4614 - val_accuracy: 0.8236
# Epoch 442/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3809 - accuracy: 0.8530 - val_loss: 0.5837 - val_accuracy: 0.7866
# Epoch 443/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4096 - accuracy: 0.8428 - val_loss: 0.6133 - val_accuracy: 0.7722
# Epoch 444/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4282 - accuracy: 0.8374 - val_loss: 0.5022 - val_accuracy: 0.7967
# Epoch 445/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4168 - accuracy: 0.8319 - val_loss: 0.4713 - val_accuracy: 0.8174
# Epoch 446/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3835 - accuracy: 0.8512 - val_loss: 0.5155 - val_accuracy: 0.8087
# Epoch 447/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4057 - accuracy: 0.8468 - val_loss: 0.5347 - val_accuracy: 0.8063
# Epoch 448/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3841 - accuracy: 0.8559 - val_loss: 0.4477 - val_accuracy: 0.8294
# Epoch 449/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3682 - accuracy: 0.8532 - val_loss: 0.4860 - val_accuracy: 0.8179
# Epoch 450/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3615 - accuracy: 0.8576 - val_loss: 0.5375 - val_accuracy: 0.7905
# Epoch 451/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3982 - accuracy: 0.8490 - val_loss: 0.4968 - val_accuracy: 0.7958
# Epoch 452/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4023 - accuracy: 0.8445 - val_loss: 0.4584 - val_accuracy: 0.8049
# Epoch 453/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3884 - accuracy: 0.8554 - val_loss: 0.4882 - val_accuracy: 0.7938
# Epoch 454/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3836 - accuracy: 0.8512 - val_loss: 0.4717 - val_accuracy: 0.8160
# Epoch 455/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.3853 - accuracy: 0.8515 - val_loss: 0.5270 - val_accuracy: 0.8039
# Epoch 456/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3855 - accuracy: 0.8550 - val_loss: 0.4752 - val_accuracy: 0.8035
# Epoch 457/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4290 - accuracy: 0.8403 - val_loss: 0.5094 - val_accuracy: 0.8097
# Epoch 458/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4208 - accuracy: 0.8377 - val_loss: 0.5052 - val_accuracy: 0.8001
# Epoch 459/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4039 - accuracy: 0.8438 - val_loss: 0.4894 - val_accuracy: 0.7996
# Epoch 460/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3859 - accuracy: 0.8511 - val_loss: 0.5511 - val_accuracy: 0.7770
# Epoch 461/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.4193 - accuracy: 0.8332 - val_loss: 0.5431 - val_accuracy: 0.7862
# Epoch 462/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4424 - accuracy: 0.8381 - val_loss: 0.4485 - val_accuracy: 0.8145
# Epoch 463/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4342 - accuracy: 0.8280 - val_loss: 0.4927 - val_accuracy: 0.8015
# Epoch 464/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3975 - accuracy: 0.8462 - val_loss: 0.4913 - val_accuracy: 0.8212
# Epoch 465/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3994 - accuracy: 0.8445 - val_loss: 0.4790 - val_accuracy: 0.8241
# Epoch 466/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.3853 - accuracy: 0.8544 - val_loss: 0.4598 - val_accuracy: 0.8217
# Epoch 467/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3885 - accuracy: 0.8502 - val_loss: 0.4533 - val_accuracy: 0.8222
# Epoch 468/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3934 - accuracy: 0.8491 - val_loss: 0.4280 - val_accuracy: 0.8400
# Epoch 469/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3750 - accuracy: 0.8542 - val_loss: 0.4786 - val_accuracy: 0.8184
# Epoch 470/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3639 - accuracy: 0.8598 - val_loss: 0.4554 - val_accuracy: 0.8150
# Epoch 471/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3703 - accuracy: 0.8594 - val_loss: 0.5353 - val_accuracy: 0.8102
# Epoch 472/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3758 - accuracy: 0.8534 - val_loss: 0.4606 - val_accuracy: 0.8270
# Epoch 473/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3558 - accuracy: 0.8641 - val_loss: 0.4360 - val_accuracy: 0.8246
# Epoch 474/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3653 - accuracy: 0.8602 - val_loss: 0.4475 - val_accuracy: 0.8241
# Epoch 475/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3545 - accuracy: 0.8648 - val_loss: 0.4628 - val_accuracy: 0.8222
# Epoch 476/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3645 - accuracy: 0.8627 - val_loss: 0.4911 - val_accuracy: 0.8083
# Epoch 477/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3727 - accuracy: 0.8581 - val_loss: 0.4336 - val_accuracy: 0.8265
# Epoch 478/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3560 - accuracy: 0.8641 - val_loss: 0.4707 - val_accuracy: 0.8164
# Epoch 479/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3661 - accuracy: 0.8607 - val_loss: 0.4337 - val_accuracy: 0.8169
# Epoch 480/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3811 - accuracy: 0.8557 - val_loss: 0.4721 - val_accuracy: 0.8198
# Epoch 481/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3721 - accuracy: 0.8581 - val_loss: 0.4452 - val_accuracy: 0.8222
# Epoch 482/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3764 - accuracy: 0.8581 - val_loss: 0.4441 - val_accuracy: 0.8284
# Epoch 483/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3608 - accuracy: 0.8600 - val_loss: 0.4420 - val_accuracy: 0.8246
# Epoch 484/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3511 - accuracy: 0.8649 - val_loss: 0.4401 - val_accuracy: 0.8232
# Epoch 485/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3589 - accuracy: 0.8616 - val_loss: 0.4140 - val_accuracy: 0.8357
# Epoch 486/500
# 9/9 [==============================] - 35s 4s/step - loss: 0.3599 - accuracy: 0.8619 - val_loss: 0.4748 - val_accuracy: 0.8184
# Epoch 487/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3760 - accuracy: 0.8545 - val_loss: 0.5054 - val_accuracy: 0.8020
# Epoch 488/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3655 - accuracy: 0.8580 - val_loss: 0.4504 - val_accuracy: 0.8270
# Epoch 489/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3710 - accuracy: 0.8607 - val_loss: 0.5135 - val_accuracy: 0.7982
# Epoch 490/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3929 - accuracy: 0.8461 - val_loss: 0.4671 - val_accuracy: 0.8203
# Epoch 491/500
# 9/9 [==============================] - 38s 4s/step - loss: 0.3706 - accuracy: 0.8566 - val_loss: 0.4159 - val_accuracy: 0.8462
# Epoch 492/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3846 - accuracy: 0.8538 - val_loss: 0.4149 - val_accuracy: 0.8337
# Epoch 493/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3646 - accuracy: 0.8568 - val_loss: 0.4676 - val_accuracy: 0.8208
# Epoch 494/500
# 9/9 [==============================] - 37s 4s/step - loss: 0.3734 - accuracy: 0.8564 - val_loss: 0.4649 - val_accuracy: 0.8107
# Epoch 495/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3542 - accuracy: 0.8631 - val_loss: 0.4598 - val_accuracy: 0.8241
# Epoch 496/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3481 - accuracy: 0.8671 - val_loss: 0.4492 - val_accuracy: 0.8232
# Epoch 497/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3513 - accuracy: 0.8621 - val_loss: 0.5791 - val_accuracy: 0.7958
# Epoch 498/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4132 - accuracy: 0.8487 - val_loss: 0.5008 - val_accuracy: 0.7794
# Epoch 499/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.4295 - accuracy: 0.8277 - val_loss: 0.4823 - val_accuracy: 0.8222
# Epoch 500/500
# 9/9 [==============================] - 36s 4s/step - loss: 0.3908 - accuracy: 0.8526 - val_loss: 0.5161 - val_accuracy: 0.8054
# -----------------------------------------------------------------
# Training was completed in 18880.74 secs
# -----------------------------------------------------------------

# %%
model.save("model_CNN_disc_feat.keras")

# %%
# Evaluate the model:
train_loss, train_accuracy = model.evaluate([X_train_partial[:,:-num_discrete_features], X_train_partial[:,-num_discrete_features:]],
                                       y_train_partial,
                                       batch_size=1024,
                                       verbose=1)

test_loss, test_accuracy = model.evaluate([X_val[:,:-num_discrete_features], X_val[:,-num_discrete_features:]],
                                                    y_val,
                                                    batch_size=1024,
                                                    verbose=1)
print('-'*65)
print(f'train accuracy = {round(train_accuracy * 100, 4)}%')
print(f'test accuracy = {round(test_accuracy * 100, 4)}%')


# Plot the loss and accuracy curves over epochs:
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(45,15))
axs[0].plot(History.history['loss'], color='b', label='Training loss')
axs[0].plot(History.history['val_loss'], color='r', label='Validation loss')
axs[0].set_title("Loss curves")
axs[0].grid()
axs[0].set_ylim((0,2))
axs[0].legend(loc='best', shadow=True)
axs[1].plot(History.history['accuracy'], color='b', label='Training accuracy')
axs[1].plot(History.history['val_accuracy'], color='r', label='Validation accuracy')
axs[1].set_title("Accuracy curves")
axs[1].grid()
axs[1].legend(loc='best', shadow=True)
plt.show()

y_pred = model.predict([X_val[:,:-num_discrete_features], X_val[:,-num_discrete_features:]])
print(f1_score(y_val.argmax(axis=1), y_pred.argmax(axis=1), average='micro'))
# Out:
# 9/9 [==============================] - 8s 856ms/step - loss: 0.3615 - accuracy: 0.8642
# 3/3 [==============================] - 2s 490ms/step - loss: 0.5161 - accuracy: 0.8054
# -----------------------------------------------------------------
# train accuracy = 86.4215%
# test accuracy = 80.5382%
# 66/66 [==============================] - 3s 37ms/step
# 0.8053820278712157

# %%
y_test_pred_np = model.predict([X_test_ready_np[:,:-num_discrete_features], X_test_ready_np[:,-num_discrete_features:]])

y_test_pred_class_np = y_test_pred_np.argmax(axis=1)

y_test_pred_class = pd.DataFrame(data={'id': range(y_test_pred_class_np.shape[0]), 'y': y_test_pred_class_np})
y_test_pred_class.to_csv('sol_CNN_with_discrete_features.csv', columns=['id', 'y'], index = False)
# Out:
# 107/107 [==============================] - 4s 37ms/step

# %%
defefdefe

# %%
# Model parameters
input_shape = (X_train_partial.shape[1], 1)  # Replace 'None' with your input length
num_classes = 4
dropout_rate = 0.3
dropout = .3
recurrent_dropout = .4

model = Sequential()

model.add(LSTM(input_shape=input_shape,
            units=32,
            activation='tanh',
            recurrent_activation='hard_sigmoid',
            dropout=dropout,
            recurrent_dropout=recurrent_dropout,
            return_sequences=True,
            return_state=False,
            stateful=False,
            unroll=False
            ))
model.add(BatchNormalization())
model.add(LSTM(units=32,
            activation='tanh',
            recurrent_activation='hard_sigmoid',
            dropout=dropout,
            recurrent_dropout=recurrent_dropout,
            return_sequences=True,
            return_state=False,
            stateful=False,
            unroll=False
            ))
model.add(BatchNormalization())

fc_neurons = [64, 64, 32]
for neurons in fc_neurons:
    model.add(Dense(neurons, activation='relu'))
    model.add(Dropout(dropout_rate))

# Softmax output layer
model.add(Dense(num_classes, activation='softmax'))

# Compile the model with Adam optimizer
model.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate))
print(model.summary())

# Model summary
model.summary()

# %%
start = time.time()
History = model.fit(X_train_partial,
                    y_train_partial,
                    epochs=50,
                    batch_size=1024,
                    validation_split=0.0,
                    validation_data=(X_val, y_val),
                    shuffle=True,
                    verbose=1)

print('-'*65)
print(f'Training was completed in {time.time() - start:.2f} secs')
print('-'*65)
model.save("model_LSTM.keras")

# %%
# Evaluate the model:
train_loss, train_accuracy = model.evaluate(X_train_partial,
                                       y_train_partial,
                                       batch_size=X_train_partial.shape[1],
                                       verbose=1)

test_loss, test_accuracy = model.evaluate(X_val,
                                                    y_val,
                                                    batch_size=X_train_partial.shape[1],
                                                    verbose=1)
print('-'*65)
print(f'train accuracy = {round(train_accuracy * 100, 4)}%')
print(f'test accuracy = {round(test_accuracy * 100, 4)}%')


# Plot the loss and accuracy curves over epochs:
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(45,15))
axs[0].plot(History.history['loss'], color='b', label='Training loss')
axs[0].plot(History.history['val_loss'], color='r', label='Validation loss')
axs[0].set_title("Loss curves")
axs[0].grid()
axs[0].legend(loc='best', shadow=True)
axs[1].plot(History.history['accuracy'], color='b', label='Training accuracy')
axs[1].plot(History.history['val_accuracy'], color='r', label='Validation accuracy')
axs[1].set_title("Accuracy curves")
axs[1].grid()
axs[1].legend(loc='best', shadow=True)
plt.show()

y_pred = model.predict(X_val)
print(f1_score(y_val.argmax(axis=1), y_pred.argmax(axis=1), average='micro'))
# Out:
# 1/1 [==============================] - 8s 8s/step - loss: 0.1122 - accuracy: 0.9604
# 1/1 [==============================] - 2s 2s/step - loss: 0.3024 - accuracy: 0.9005
# -----------------------------------------------------------------
# train accuracy = 96.035%
# test accuracy = 90.0461%
# 68/68 [==============================] - 3s 38ms/step
# 0.9004608294930876

# %%
y_test_pred_np = model.predict(X_test_ready_np)

y_test_pred_class_np = y_test_pred_np.argmax(axis=1)

y_test_pred_class = pd.DataFrame(data={'id': range(y_test_pred_class_np.shape[0]), 'y': y_test_pred_class_np})
y_test_pred_class.to_csv('sol_bigger.csv', columns=['id', 'y'], index = False)
# Out:
# 107/107 [==============================] - 4s 39ms/step

# %%
class_distribution_pred = y_test_pred_class.apply(lambda x: {i: x[x == i].count() for i in range(4)})['y']
class_distribution = y_train.apply(lambda x: {i: x[x == i].count() for i in range(4)})['y']

print('Original:')
for name in class_distribution:
    print(str(name) + ': {:2.1%}'.format(class_distribution[name] / y_train.size))
print('')
print('Pred:')
for name in class_distribution_pred:
    print(str(name) + ': {:2.1%}'.format(class_distribution_pred[name] / y_test_pred_class.shape[0]))
# Out:
# Original:
# 0: 59.2%
# 1: 8.7%
# 2: 28.8%
# 3: 3.3%
#
# Pred:
# 0: 63.1%
# 1: 11.0%
# 2: 23.7%
# 3: 2.1%

# %%
# Define a learning rate decay method:
lr_decay = ReduceLROnPlateau(monitor='loss', 
                             patience=5,
                             verbose=0,
                             factor=0.5,
                             min_lr=1e-8)

# Define Early Stopping:
early_stop = EarlyStopping(monitor='val_accuracy',
                           min_delta=0, 
                           patience=100,
                           verbose=1,
                           mode='max',
                           baseline=0.8,
                           start_from_epoch=1,
                           restore_best_weights=True)

callbacks=[lr_decay, early_stop]
